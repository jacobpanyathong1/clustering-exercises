# %%
import acquire as a

# %%
a.get_mall_customers()
# Out:
#      Unnamed: 0  customer_id  gender  age  annual_income  spending_score
# 0             0            1    Male   19             15              39
# 1             1            2    Male   21             15              81
# 2             2            3  Female   20             16               6
# 3             3            4  Female   23             16              77
# 4             4            5  Female   31             17              40
# ..          ...          ...     ...  ...            ...             ...
# 195         195          196  Female   35            120              79
# 196         196          197  Female   45            126              28
# 197         197          198    Male   32            126              74
# 198         198          199    Male   32            137              18
# 199         199          200    Male   30            137              83
#
# [200 rows x 6 columns]

# %%
a.get_zillow()
# Out:
# /Users/jp/codeup-data-science/clustering-exercises/acquire.py:30: DtypeWarning: Columns (64) have mixed types. Specify dtype option on import or set low_memory=False.
#   return pd.read_csv(filename)
#        parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 0      14297519                     NaN          NaN                  261.0
# 1      17052889                     NaN          NaN                  261.0
# 2      14186244                     NaN          NaN                  261.0
# 3      12177905                     NaN          NaN                  261.0
# 4      10887214                     NaN          NaN                  266.0
# ...         ...                     ...          ...                    ...
# 77574  10833991                     NaN          NaN                  266.0
# 77575  11000655                     NaN          NaN                  261.0
# 77576  17239384                     NaN          NaN                  261.0
# ...
