# %%
import pandas as pd
import acquire as a
import numpy as np

# %% [markdown]
# ## Acquire

# %% [markdown]
# #### Gathering Zillow Data

# %%
a.get_mall_customers()
# Out:
#      Unnamed: 0  customer_id  gender  age  annual_income  spending_score
# 0             0            1    Male   19             15              39
# 1             1            2    Male   21             15              81
# 2             2            3  Female   20             16               6
# 3             3            4  Female   23             16              77
# 4             4            5  Female   31             17              40
# ..          ...          ...     ...  ...            ...             ...
# 195         195          196  Female   35            120              79
# 196         196          197  Female   45            126              28
# 197         197          198    Male   32            126              74
# 198         198          199    Male   32            137              18
# 199         199          200    Male   30            137              83
#
# [200 rows x 6 columns]

# %%
df = a.get_zillow() # Zillow DataFrame

# %% [markdown]
# ## Summary of Data

# %%
df.describe().T # Summary stats
# Out:
#                                 count          mean           std  \
# parcelid                      77579.0  1.300828e+07  3.519399e+06
# typeconstructiontypeid          223.0  6.040359e+00  5.560348e-01
# storytypeid                      50.0  7.000000e+00  0.000000e+00
# propertylandusetypeid         77579.0  2.618245e+02  5.141596e+00
# heatingorsystemtypeid         49571.0  3.921749e+00  3.594780e+00
# buildingclasstypeid              15.0  3.933333e+00  2.581989e-01
# architecturalstyletypeid        207.0  7.386473e+00  2.728030e+00
# airconditioningtypeid         25007.0  1.812013e+00  2.965768e+00
# id                            77579.0  1.495392e+06  8.609686e+05
# basementsqft                     50.0  6.797200e+02  6.897035e+02
# bathroomcnt                   77579.0  2.298496e+00  9.967317e-01
# bedroomcnt                    77579.0  3.053223e+00  1.140480e+00
# buildingqualitytypeid         49809.0  6.533779e+00  1.722062e+00
# ...

# %%
df.info() #columns and dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77579 entries, 0 to 77578
# Data columns (total 69 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      77579 non-null  int64
#  1   typeconstructiontypeid        223 non-null    float64
#  2   storytypeid                   50 non-null     float64
#  3   propertylandusetypeid         77579 non-null  float64
#  4   heatingorsystemtypeid         49571 non-null  float64
#  5   buildingclasstypeid           15 non-null     float64
#  6   architecturalstyletypeid      207 non-null    float64
#  7   airconditioningtypeid         25007 non-null  float64
#  8   id                            77579 non-null  int64
#  9   basementsqft                  50 non-null     float64
#  10  bathroomcnt                   77579 non-null  float64
#  11  bedroomcnt                    77579 non-null  float64
# ...

# %%
col = df.columns #columns

# %%
col
# Out:
# Index(['parcelid', 'typeconstructiontypeid', 'storytypeid',
#        'propertylandusetypeid', 'heatingorsystemtypeid', 'buildingclasstypeid',
#        'architecturalstyletypeid', 'airconditioningtypeid', 'id',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid',
#        'calculatedbathnbr', 'decktypeid', 'finishedfloor1squarefeet',
#        'calculatedfinishedsquarefeet', 'finishedsquarefeet12',
#        'finishedsquarefeet13', 'finishedsquarefeet15', 'finishedsquarefeet50',
#        'finishedsquarefeet6', 'fips', 'fireplacecnt', 'fullbathcnt',
#        'garagecarcnt', 'garagetotalsqft', 'hashottuborspa', 'latitude',
#        'longitude', 'lotsizesquarefeet', 'poolcnt', 'poolsizesum',
#        'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertycountylandusecode', 'propertyzoningdesc',
#        'rawcensustractandblock', 'regionidcity', 'regionidcounty',
#        'regionidneighborhood', 'regionidzip', 'roomcnt', 'threequarterbathnbr',
# ...

# %% [markdown]
# ###### Write a function that takes in a dataframe of observations and attributes and returns a dataframe where each row is an atttribute name, the first column is the number of rows with missing values for that attribute, and the second column is percent of total rows that have missing values for that attribute. Run the function and document takeaways from this on how you want to handle missing values

# %%
# function for missing rows and pct of missing rows

# %%
s= df.isna().sum()
pd.Series(s).values
# Out:
# array([    0, 77356, 77529,     0, 28008, 77564, 77372, 52572,     0,
#        77529,     0,     0, 27770,   616, 76965, 71542,   201,  3656,
#        77537, 74552, 71542, 77193,     0, 69290,   616, 52059, 52059,
#        76040,     0,     0,  8258, 61405, 76710, 77114, 76505, 62500,
#            0, 27103,     0,  1472,     0, 46605,    50,     0, 67473,
#        26876, 75186, 77509,   270, 59980, 77407,   115,     1,     0,
#            2,     5, 74679, 74679,   247,     0,     0,     0, 52572,
#        77372, 77564, 28008,     0, 77529, 77356])

# %%
def row_col(df):
    b = list(df.columns)
    a= df.isna().sum()
    d= pd.Series(a).values
    c= {'columns': b, 'num_rows_missing' : d, 'pct_rows_missing' : a/len(df)}
    df = pd.DataFrame(data=c)
    df.reset_index(inplace=True)
    return df

# %%
n_df= row_col(df)

# %%
n_df
# Out:
#                      index                 columns  num_rows_missing  \
# 0                 parcelid                parcelid                 0
# 1   typeconstructiontypeid  typeconstructiontypeid             77356
# 2              storytypeid             storytypeid             77529
# 3    propertylandusetypeid   propertylandusetypeid                 0
# 4    heatingorsystemtypeid   heatingorsystemtypeid             28008
# ..                     ...                     ...               ...
# 64       buildingclassdesc       buildingclassdesc             77564
# 65     heatingorsystemdesc     heatingorsystemdesc             28008
# 66     propertylandusedesc     propertylandusedesc                 0
# 67               storydesc               storydesc             77529
# 68    typeconstructiondesc    typeconstructiondesc             77356
#
#     pct_rows_missing
# 0           0.000000
# 1           0.997126
# 2           0.999355
# 3           0.000000
# 4           0.361026
# ...

# %% [markdown]
# ## Prepare

# %%
df.columns
# Out:
# Index(['parcelid', 'typeconstructiontypeid', 'storytypeid',
#        'propertylandusetypeid', 'heatingorsystemtypeid', 'buildingclasstypeid',
#        'architecturalstyletypeid', 'airconditioningtypeid', 'id',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid',
#        'calculatedbathnbr', 'decktypeid', 'finishedfloor1squarefeet',
#        'calculatedfinishedsquarefeet', 'finishedsquarefeet12',
#        'finishedsquarefeet13', 'finishedsquarefeet15', 'finishedsquarefeet50',
#        'finishedsquarefeet6', 'fips', 'fireplacecnt', 'fullbathcnt',
#        'garagecarcnt', 'garagetotalsqft', 'hashottuborspa', 'latitude',
#        'longitude', 'lotsizesquarefeet', 'poolcnt', 'poolsizesum',
#        'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertycountylandusecode', 'propertyzoningdesc',
#        'rawcensustractandblock', 'regionidcity', 'regionidcounty',
#        'regionidneighborhood', 'regionidzip', 'roomcnt', 'threequarterbathnbr',
# ...

# %%
df['propertylandusedesc'].value_counts() # value_counts of str
# Out:
# Single Family Residential                     52441
# Condominium                                   19342
# Duplex (2 Units, Any Combination)              2021
# Planned Unit Development                       1947
# Quadruplex (4 Units, Any Combination)           729
# Triplex (3 Units, Any Combination)              539
# Cluster Home                                    335
# Mobile Home                                      74
# Manufactured, Modular, Prefabricated Homes       59
# Residential General                              42
# Cooperative                                      29
# Commercial/Office/Residential Mixed Used         15
# Townhouse                                         6
# Name: propertylandusedesc, dtype: int64

# %% [markdown]
# ###### Remove any properties that are likely to be something other than single unit properties. (e.g. no duplexes, no land/lot, ...). There are multiple ways to estimate that a property is a single unit, and there is not a single "right" answer.

# %%
single_df = df.loc[df['propertylandusedesc'] != df.propertylandusedesc.str.contains('unit')] # DataFrame of just the single units

# %% [markdown]
# ###### Create a function that will drop rows or columns based on the percent of values that are missing: handle_missing_values(df, prop_required_column, prop_required_row).

# %%
def handle_missing_values(df, prop_required_column, prop_required_row):
    b = list(df.columns)
    a= df.isna().sum()
    d= pd.Series(a).values
    c= {'columns': b,'num_rows_missing' : d, 'pct_rows_missing' : a/len(df)}
    new_df = pd.DataFrame(data=c)
    new_df.reset_index(drop=True, inplace=True)
    
    cols = df.columns
    for col in cols:
        if new_df.pct_rows_missing >= prop_required_row & :
            df.dropna(thresh = "{:.0%}".format({prop_required_row}), inplace=True)
        if df.num_rows_missing >= prop_required_column:
            df.drop(columns=[col], inplace=True) 
            return df

# %%
handle_missing_values(df, .60, .75)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/51/1y9bskdx161fnwxyf68jcl540000gn/T/ipykernel_33665/801265057.py in <module>
# ----> 1 handle_missing_values(df, .60, .75)
#
# /var/folders/51/1y9bskdx161fnwxyf68jcl540000gn/T/ipykernel_33665/2860370505.py in handle_missing_values(df, prop_required_column, prop_required_row)
#       9     cols = df.columns
#      10     for col in cols:
# ---> 11         if new_df.pct_rows_missing:
#      12             df.dropna(thresh = "{:.0%}".format({prop_required_row}), inplace=True)
#      13         if df.num_rows_missing >= prop_required_column:
#
# /opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1525     @final
#    1526     def __nonzero__(self):
# -> 1527         raise ValueError(
#    1528             f"The truth value of a {type(self).__name__} is ambiguous. "
# ...

# %%
b = list(df.columns)
a= df.isna().sum()
d= pd.Series(a).values
c= {'columns': b,'num_rows_missing' : d, 'pct_rows_missing' : a/len(df)}
new_df = pd.DataFrame(data=c)
new_df.reset_index(drop=True, inplace=True)


cols = df.columns

# %%
new_df['columns'][0:]
# Out:
# 0                   parcelid
# 1     typeconstructiontypeid
# 2                storytypeid
# 3      propertylandusetypeid
# 4      heatingorsystemtypeid
#                ...
# 64         buildingclassdesc
# 65       heatingorsystemdesc
# 66       propertylandusedesc
# 67                 storydesc
# 68      typeconstructiondesc
# Name: columns, Length: 69, dtype: object
